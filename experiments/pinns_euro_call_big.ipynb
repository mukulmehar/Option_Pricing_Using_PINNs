# %%
import torch
import torch.autograd as tgrad
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import pandas as pd
import os
from european_utils import EuropeanOptionData, plot_solution
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
class PINNs(nn.Module):
  def __init__(self, in_dim, out_dim, hidden_dim, num_layer):
    super(PINNs, self).__init__()

    layers = []
    for i in range(num_layer - 1):
      if i == 0:
        layers.append(nn.Linear(in_features=in_dim, out_features=hidden_dim))
        layers.append(nn.Tanh())
      else:
        layers.append(nn.Linear(in_features=hidden_dim, out_features=hidden_dim))
        layers.append(nn.Tanh())

    layers.append(nn.Linear(in_features=hidden_dim, out_features=out_dim))

    self.linear = nn.Sequential(*layers)

  def forward(self, x):
    # src = torch.cat((x, t), dim=-1)
    return self.linear(x)

# %%
def init_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)

# %%
N_EPOCH = 80000
LEARNING_RATE = 1e-5
HIDDEN_LAYER = 5
HIDDEN_WIDTH = 256
N_sample = 8000
EXPERIMENT_NAME = "exp_euro_call"
PHYSICS_PENALTY = 52
MODEL_TYPE = PINNs
BVP1_PENALTY = 8
ERR_SAMPLING = False

experiment_dir = f"./{EXPERIMENT_NAME}"
os.makedirs(experiment_dir, exist_ok=True)

# %%
import logging
from datetime import datetime
logger = logging.getLogger()
current_date = datetime.now().strftime("%Y-%m-%d")
log_file_name = f"{experiment_dir}/{EXPERIMENT_NAME}_log_{current_date}.log"
fhandler = logging.FileHandler(filename=log_file_name, mode='w')
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
fhandler.setFormatter(formatter)
logger.addHandler(fhandler)
logger.setLevel(logging.INFO)

# %%
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.set_default_device(DEVICE)
logging.info(f"Running on device={DEVICE}")

# %% [markdown]
# ### Parameters for the experiment

# %%
logging.info(f"N_EPOCH: {N_EPOCH}")
logging.info(f"LEARNING_RATE: {LEARNING_RATE}")
logging.info(f"HIDDEN_LAYER: {HIDDEN_LAYER}")
logging.info(f"HIDDEN_WIDTH: {HIDDEN_WIDTH}")
logging.info(f"N_sample: {N_sample}")
logging.info(f"EXPERIMENT_NAME: {EXPERIMENT_NAME}")
logging.info(f"PHYSICS_PENALTY: {PHYSICS_PENALTY}")
logging.info(f"BVP1_PENALTY: {BVP1_PENALTY}")
logging.info(f"ERR_SAMPLING: {ERR_SAMPLING}")
logging.info(f"Model type: {MODEL_TYPE.__name__}")

# %% [markdown]
# #### Parameters for European Call

# %%
K = 40
r = 0.05
sigma = 0.2
T = 1
S_range = [0, 160]
t_range = [0, T]

# %%
euro_call_data = EuropeanOptionData(t_range,S_range,K,r,sigma)

# %%
bvp_x1,bvp_y1,bvp_x2,bvp_y2 = euro_call_data.get_bvp_data(500,1,1)
ivp_x1,ivp_y1 = euro_call_data.get_ivp_data(500,1)
diff_x1,diff_y1 = euro_call_data.get_diff_data(2000)
plt.scatter(bvp_x1[:,0],bvp_x1[:,1], label= "BVP 1", color = "red",marker="o")
plt.scatter(bvp_x2[:,0],bvp_x2[:,1], label= "BVP 2", color = "green",marker="x")
plt.scatter(ivp_x1[:,0],ivp_x1[:,1], label= "IVP", color = "blue")
plt.scatter(diff_x1[:,0],diff_x1[:,1], label= "PDE sample", color = "grey", alpha = 0.3)
plt.xlabel(f"current time (t), $t \in (0,1)$")
plt.ylabel("stock price $S$")
plt.title("Data Sampling for European Call")
plt.legend()

# %% [markdown]
# #### Train Model

# %%
model = MODEL_TYPE(2,1,HIDDEN_WIDTH, HIDDEN_LAYER + 1).to(DEVICE)
model.apply(init_weights)
logging.info(f"Model parameters : {sum(p.numel() for p in model.parameters())/10**3:.2f}K")

# %%
# N_sample = 500
physics_lr = PHYSICS_PENALTY
optimizer = torch.optim.Adam(model.parameters(),lr=LEARNING_RATE)

loss_history={
    "total_loss":[],"loss_ivp_bvp":[],"loss_BS":[],\
    "loss_bvp1":[],"loss_bvp2":[],"loss_ivp":[],
}

# %% [markdown]
# * BVP1 $S = S_{min}: \quad 0$
# * BVP2 $(S = S_{max}): \quad S_{max} - K.e^{-rt}$
# * IVP (t = T): $\quad max(S - K, 0)$

# %%
def get_sample_rt(l1,l2,l3):
    t = l1+l2+l3
    l1 = max(l1*3/t,0.25)
    l2 = max(l2*3/t,0.25)
    l3 = max(l3*3/t,0.25)
    return (l1,l2,l3)

# %%
r_ivp,r_bvp1,r_bvp2 = 1,1,1
for i in range(N_EPOCH):
    model.train();
    # Get IVP data
    ivp_x_tensor,ivp_y_tensor = euro_call_data.get_ivp_data_tensor(N_sample,r_ivp)
    ivp_x_tensor = ivp_x_tensor.to(DEVICE)
    ivp_y_tensor = ivp_y_tensor.to(DEVICE)
    # ivp_x_tensor = euro_call_data.normalize(ivp_x_tensor)
    ivp_y_pred = model(ivp_x_tensor)
    mse_ivp = nn.MSELoss()(ivp_y_tensor, ivp_y_pred)

    # Get BVP data
    bvp_x1_tensor,bvp_y1_tensor,bvp_x2_tensor,bvp_y2_tensor = euro_call_data.get_bvp_data_tensor(N_sample,r_bvp1,r_bvp2)
    bvp_x1_tensor,bvp_y1_tensor = bvp_x1_tensor.to(DEVICE),bvp_y1_tensor.to(DEVICE)
    bvp_x2_tensor,bvp_y2_tensor = bvp_x2_tensor.to(DEVICE),bvp_y2_tensor.to(DEVICE)
    # bvp_x1_tensor = euro_call_data.normalize(bvp_x1_tensor)
    bvp_y1_pred = model(bvp_x1_tensor)
    mse_bvp1 = nn.MSELoss()(bvp_y1_tensor, bvp_y1_pred)
    # bvp_x2_tensor = euro_call_data.normalize(bvp_x2_tensor)
    bvp_y2_pred = model(bvp_x2_tensor)
    mse_bvp2 = nn.MSELoss()(bvp_y2_tensor, bvp_y2_pred)

    # Aggregate the "data loss"
    loss1 = mse_ivp + BVP1_PENALTY*mse_bvp1 + mse_bvp2

    # Compute the "Black-Scholes loss"
    X1,y1 = euro_call_data.get_diff_data(N_sample)
    X1 = torch.from_numpy(X1).float().requires_grad_().to(DEVICE)
    y1 = torch.from_numpy(y1).float().to(DEVICE)
    y1_hat = model(X1)
    grads = torch.autograd.grad(y1_hat, X1, grad_outputs=torch.ones(y1_hat.shape).to(DEVICE), retain_graph=True, create_graph=True, only_inputs=True)[0]
    dVdt, dVdS = grads[:, 0].view(-1, 1), grads[:, 1].view(-1, 1)
    grads2nd = torch.autograd.grad(dVdS, X1, grad_outputs=torch.ones(dVdS.shape).to(DEVICE), create_graph=True, only_inputs=True)[0]
    d2VdS2 = grads2nd[:, 1].view(-1, 1)
    S1 = X1[:, 1].view(-1, 1)
    bs_pde = dVdt + (0.5 * ((sigma * S1) ** 2) * d2VdS2) + (r * S1 * dVdS)
    loss2 = physics_lr * nn.MSELoss()(bs_pde, torch.zeros_like(r * y1_hat))

    # Backpropagate joint loss
    loss = loss1 + loss2
    loss_history["total_loss"].append(loss.item())
    loss_history["loss_ivp_bvp"].append(loss1.item())
    loss_history["loss_BS"].append(loss2.item())
    loss_history["loss_ivp"].append(mse_ivp.item())
    loss_history["loss_bvp1"].append(mse_bvp1.item())
    loss_history["loss_bvp2"].append(mse_bvp2.item())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    #normalise the ratios
    if ERR_SAMPLING:
      r_ivp,r_bvp1,r_bvp2 = get_sample_rt(mse_ivp.item(),mse_bvp1.item(),mse_bvp2.item())
    # Plot the result as training progresses
    if (i + 1) % 500 == 0:
        logging.info(f"Epoch {i+1}, Loss: {loss.item():.4f}")
        if DEVICE.type !="cuda":
          print(f"Epoch {i+1}, Loss: {loss.item():.4f}")
    if (i+1) % 1000 == 0:
      plot_solution(model, euro_call_data, i+1, experiment_dir)

# %% [markdown]
# #### Training Curve

# %%
loss_df = pd.DataFrame.from_dict(loss_history)
ax = loss_df[["total_loss"]].plot(logy=True,alpha=0.8)
loss_df[["total_loss"]].rename(columns={"total_loss":"MA loss"}).rolling(10).mean().plot(logy=True,alpha=0.8, label="MA", ax = ax)
plt.title("Total Training loss")
plt.savefig(experiment_dir+"/total_loss.jpg")

# %%
tail_result = loss_df.rolling(50).mean().tail(1)
logging.info(f"Loss results")
logging.info(f"{tail_result}")

# %%
loss_df.rolling(10).mean().plot(logy=True,alpha=0.8, subplots = True)
# plt.title("Training Curve for Moving Average of losses")
plt.savefig(experiment_dir+"/ivp_bs_loss.jpg")

# %% [markdown]
# #### Visualization

# %%
# %matplotlib inline

# %%
s = np.linspace(S_range[0], S_range[1], 100)
t = np.linspace(t_range[0], t_range[1], 100)
s_grid, t_grid = np.meshgrid(s, t)
s_flat = s_grid.flatten()
t_flat = t_grid.flatten()
# Create a 2D tensor from the flattened arrays
X_test = torch.tensor(np.column_stack((t_flat, s_flat)), dtype=torch.float)
# X_test_norm = euro_call_data.normalize(X_test)
y_analytical_test = euro_call_data.get_analytical_soln(X_test[:,1],X_test[:,0])
model.eval();
with torch.no_grad():
  y_pinn_test = model(X_test)
# Create the 3D plot
fig = plt.figure(figsize=(14,7))
ax = fig.add_subplot(121, projection='3d')
ax.plot_surface(s_grid, t_grid, y_analytical_test.cpu().numpy().reshape(s_grid.shape), cmap = "viridis")
ax.set_title("Analytical Soln")
ax.set_xlabel("Spot Price")
ax.set_ylabel(r'current time $(\tau)$, $\tau \in {%s}$' %t_range)
ax.set_zlabel("Call price")
ax.view_init(elev=20, azim=-120)
ax = fig.add_subplot(122, projection='3d')
ax.plot_surface(s_grid, t_grid, y_pinn_test.cpu().numpy().reshape(s_grid.shape), cmap = "viridis")
ax.set_title("PINN prediction")
ax.set_xlabel("Spot Price")
ax.set_ylabel(r'current time $(\tau)$, $\tau \in {%s}$' %t_range)
ax.set_zlabel("Call price")
ax.view_init(elev=20, azim=-120)
plt.savefig(experiment_dir+f"/true_vs_pred_final.jpg")

# %%
y_pinn_test
# Out:
# tensor([[ 1.4332e-02],
#         [ 6.5943e-02],
#         [-8.5087e-03],
#         ...,
#         [ 1.1672e+02],
#         [ 1.1824e+02],
#         [ 1.1974e+02]], device='cuda:0')

# %%
# %matplotlib inline

# %%
fig = plt.figure(figsize=(14,7))
ax = fig.add_subplot(121, projection='3d')
err = y_pinn_test.cpu().numpy().reshape(s_grid.shape) - y_analytical_test.cpu().numpy().reshape(s_grid.shape)
ax.plot_surface(s_grid, t_grid, err, cmap = "viridis")
ax.plot_surface(s_grid, t_grid, np.zeros(err.shape), color = "grey")
ax.set_title("Analytical Soln - Predicted")
ax.set_xlabel("Spot Price")
ax.set_ylabel("Time to expiry")
ax.set_zlabel("Call price")
ax.view_init(elev=20, azim=-120)
plt.show()

# %%
err = (y_pinn_test-y_analytical_test.reshape(y_analytical_test.shape[0],-1)).cpu().numpy()
loss_mse = np.square(err).sum()/(len(err))
print(f"MSE net: {loss_mse:.3f}")
logging.info(f"MSE net: {loss_mse:.3f}")
# Out:
# MSE net: 1.858

# %% [markdown]
# #### Correlation

# %%
# %matplotlib inline

# %%
plt.scatter(x= y_pinn_test.cpu().numpy(), y = y_analytical_test.cpu().numpy(), marker = "x", alpha = 0.5)
plt.plot([min(y_pinn_test.cpu().numpy().min(), y_analytical_test.cpu().numpy().min()),\
          max(y_pinn_test.cpu().numpy().max(), y_analytical_test.cpu().numpy().max())],
         [min(y_pinn_test.cpu().numpy().min(), y_analytical_test.cpu().numpy().min()),\
          max(y_pinn_test.cpu().numpy().max(), y_analytical_test.cpu().numpy().max())],
         linestyle='--', color='red', label='Diagonal line')
plt.xlabel("PINN prediction")
plt.ylabel("Analytical solution")
plt.title("European Call Option pricing")
plt.savefig(experiment_dir+"/true_vs_pred_coef.jpg")
coef_res = np.corrcoef(y_pinn_test.cpu().numpy().reshape(y_pinn_test.shape[0],),y_analytical_test.cpu().numpy())
logging.info(f"Coef: {coef_res[0,1]:.3f}")
print(f"Coef: {coef_res[0,1]:.3f}")
# Out:
# Coef: 1.000

# %%
torch.save(model.state_dict(), f"{experiment_dir}/model_path")

# %%
plt.scatter(x= y_analytical_test.cpu().numpy(), y=err, marker = ".", alpha = 0.5)
plt.axhline(0,linestyle="--",color="r")
plt.xlabel("PINN prediction")
plt.ylabel("Error = $y_{true} - y_{pinn}$")
plt.title("European Call Option pricing")
plt.savefig(experiment_dir+"/true_vs_pred_error1.jpg")

# %%
# !zip -r ./{experiment_dir}.zip $experiment_dir
# Out:
#   adding: exp_euro_call/ (stored 0%)
#   adding: exp_euro_call/true_vs_pred_70000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_3000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_4000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_63000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_79000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_80000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_51000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_67000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_50000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_28000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_coef.jpg (deflated 30%)
#   adding: exp_euro_call/exp_euro_call_log_2024-05-27.log (deflated 78%)
#   adding: exp_euro_call/true_vs_pred_40000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_15000.jpg (deflated 14%)
#   adding: exp_euro_call/model_path (deflated 8%)
#   adding: exp_euro_call/true_vs_pred_34000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_48000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_54000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_16000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_24000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_53000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_73000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_43000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_62000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_22000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_35000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_33000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_38000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_19000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_78000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_final.jpg (deflated 13%)
#   adding: exp_euro_call/true_vs_pred_74000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_12000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_error1.jpg (deflated 13%)
#   adding: exp_euro_call/true_vs_pred_66000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_9000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_8000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_52000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_56000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_41000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_10000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_75000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_76000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_77000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_1000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_47000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_45000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_69000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_20000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_64000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_27000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_30000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_68000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_14000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_26000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_44000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_29000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_46000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_60000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_36000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_72000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_55000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_31000.jpg (deflated 15%)
#   adding: exp_euro_call/ivp_bs_loss.jpg (deflated 25%)
#   adding: exp_euro_call/true_vs_pred_61000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_23000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_7000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_21000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_37000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_42000.jpg (deflated 15%)
#   adding: exp_euro_call/total_loss.jpg (deflated 30%)
#   adding: exp_euro_call/true_vs_pred_49000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_71000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_65000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_59000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_6000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_13000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_58000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_32000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_17000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_11000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_25000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_57000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_18000.jpg (deflated 14%)
#   adding: exp_euro_call/true_vs_pred_39000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_2000.jpg (deflated 15%)
#   adding: exp_euro_call/true_vs_pred_5000.jpg (deflated 15%)
